# %% [markdown]
#   DATA PREPROCESSING AND FEATURE ENGINEERING IN MACHINE LEARNING
#
# Data Loading & Basic Exploration:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
adult= pd.read_csv('/content/adult_with_headers (1).csv')

# %%
adult
# Out:
#        age          workclass  fnlwgt      education  education_num  \
# 0       39          State-gov   77516      Bachelors           13.0
# 1       50   Self-emp-not-inc   83311      Bachelors           13.0
# 2       38            Private  215646        HS-grad            9.0
# 3       53            Private  234721           11th            7.0
# 4       28            Private  338409      Bachelors           13.0
# ...    ...                ...     ...            ...            ...
# 26870   38            Private  179488     Assoc-acdm           12.0
# 26871   53            Private   48343        HS-grad            9.0
# 26872   28          Local-gov  100270      Bachelors           13.0
# 26873   42            Private  227065   Some-college           10.0
# 26874   40            Private      12            NaN            NaN
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 26870             Divorced        Craft-repair   Not-in-family   White
# 26871   Married-civ-spouse    Transport-moving         Husband   White
# 26872             Divorced      Prof-specialty   Not-in-family   White
# 26873   Married-civ-spouse      Prof-specialty         Husband   White
# 26874                  NaN                 NaN             NaN     NaN
#
#            sex  capital_gain  capital_loss  hours_per_week  native_country  \
# 0         Male        2174.0           0.0            40.0   United-States
# 1         Male           0.0           0.0            13.0   United-States
# 2         Male           0.0           0.0            40.0   United-States
# 3         Male           0.0           0.0            40.0   United-States
# 4       Female           0.0           0.0            40.0            Cuba
# ...        ...           ...           ...             ...             ...
# 26870     Male           0.0           0.0            40.0   United-States
# 26871     Male           0.0        1902.0            40.0   United-States
# 26872     Male           0.0           0.0            40.0   United-States
# 26873     Male       15024.0           0.0            32.0   United-States
# 26874      NaN           NaN           NaN             NaN             NaN
#
#        income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 26870   <=50K
# 26871    >50K
# 26872   <=50K
# 26873    >50K
# 26874     NaN
#
# [26875 rows x 15 columns]

# %%
adult.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors           13.0
# 1   50   Self-emp-not-inc   83311   Bachelors           13.0
# 2   38            Private  215646     HS-grad            9.0
# 3   53            Private  234721        11th            7.0
# 4   28            Private  338409   Bachelors           13.0
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# 0        2174.0           0.0            40.0   United-States   <=50K
# 1           0.0           0.0            13.0   United-States   <=50K
# 2           0.0           0.0            40.0   United-States   <=50K
# 3           0.0           0.0            40.0   United-States   <=50K
# 4           0.0           0.0            40.0            Cuba   <=50K

# %%
adult.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  26875.000000  2.687500e+04   26874.000000  26874.000000  26874.000000
# mean      38.614512  1.897247e+05      10.084692   1091.752995     86.985376
# std       13.672291  1.051341e+05       2.564925   7501.346726    402.254353
# min       17.000000  1.200000e+01       1.000000      0.000000      0.000000
# 25%       28.000000  1.179630e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.784210e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.368785e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    26874.000000
# mean        40.408648
# std         12.302287
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
adult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26875 entries, 0 to 26874
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             26875 non-null  int64
#  1   workclass       26875 non-null  object
#  2   fnlwgt          26875 non-null  int64
#  3   education       26874 non-null  object
#  4   education_num   26874 non-null  float64
#  5   marital_status  26874 non-null  object
#  6   occupation      26874 non-null  object
#  7   relationship    26874 non-null  object
#  8   race            26874 non-null  object
#  9   sex             26874 non-null  object
#  10  capital_gain    26874 non-null  float64
#  11  capital_loss    26874 non-null  float64
#  12  hours_per_week  26874 non-null  float64
#  13  native_country  26874 non-null  object
#  14  income          26874 non-null  object
# dtypes: float64(4), int64(2), object(9)
# memory usage: 3.1+ MB

# %%
adult.isnull()
# Out:
#          age  workclass  fnlwgt  education  education_num  marital_status  \
# 0      False      False   False      False          False           False
# 1      False      False   False      False          False           False
# 2      False      False   False      False          False           False
# 3      False      False   False      False          False           False
# 4      False      False   False      False          False           False
# ...      ...        ...     ...        ...            ...             ...
# 26870  False      False   False      False          False           False
# 26871  False      False   False      False          False           False
# 26872  False      False   False      False          False           False
# 26873  False      False   False      False          False           False
# 26874  False      False   False       True           True            True
#
#        occupation  relationship   race    sex  capital_gain  capital_loss  \
# 0           False         False  False  False         False         False
# 1           False         False  False  False         False         False
# 2           False         False  False  False         False         False
# 3           False         False  False  False         False         False
# 4           False         False  False  False         False         False
# ...           ...           ...    ...    ...           ...           ...
# 26870       False         False  False  False         False         False
# 26871       False         False  False  False         False         False
# 26872       False         False  False  False         False         False
# 26873       False         False  False  False         False         False
# 26874        True          True   True   True          True          True
#
#        hours_per_week  native_country  income
# 0               False           False   False
# 1               False           False   False
# 2               False           False   False
# 3               False           False   False
# 4               False           False   False
# ...               ...             ...     ...
# 26870           False           False   False
# 26871           False           False   False
# 26872           False           False   False
# 26873           False           False   False
# 26874            True            True    True
#
# [26875 rows x 15 columns]

# %%
adult.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         1
# education_num     1
# marital_status    1
# occupation        1
# relationship      1
# race              1
# sex               1
# capital_gain      1
# capital_loss      1
# hours_per_week    1
# native_country    1
# income            1
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
num_cols=adult.select_dtypes(include=["int64","float64"]).columns
cat_cols=adult.select_dtypes(include=["object"]).columns

# %%
num_imputer=SimpleImputer(strategy="median")
cat_imputer=SimpleImputer(strategy="most_frequent")
adult[num_cols]=num_imputer.fit_transform(adult[num_cols])
adult[cat_cols]=cat_imputer.fit_transform(adult[cat_cols])

# %% [markdown]
# Feature Scaling :
#
# Standard Scaling :

# %%
from sklearn.preprocessing import StandardScaler

std_scaler = StandardScaler()
adult_standard_scaled = adult.copy()
adult_standard_scaled[num_cols] = std_scaler.fit_transform(adult[num_cols])

# %% [markdown]
# Min-Max Scaling :

# %%
from sklearn.preprocessing import MinMaxScaler

mm_scaler = MinMaxScaler()
adult_minmax_scaled = adult.copy()
adult_minmax_scaled[num_cols] = mm_scaler.fit_transform(adult[num_cols])

# %%
# Standard Scaling :
#Preferred When	: During Linear Regression, Logistic Regression, SVM, PCA
#Reason : Centers data (mean=0, std=1), assumes Gaussian distribution


#Min-Max Scaling :
#Preferred When	: Neural Networks, KNN, Distance-based models
#Reason : Keeps values in fixed range [0,1], preserves distribution

# %% [markdown]
# Encoding Techniques :
#
# One-Hot Encoding :

# %%
adult_encoding = pd.get_dummies(adult, columns=["workclass","education","marital_status","occupation","relationship","race","sex","native_country"], drop_first=True)
adult_encoding
# Out:
#         age    fnlwgt  education_num  capital_gain  capital_loss  \
# 0      39.0   77516.0           13.0        2174.0           0.0
# 1      50.0   83311.0           13.0           0.0           0.0
# 2      38.0  215646.0            9.0           0.0           0.0
# 3      53.0  234721.0            7.0           0.0           0.0
# 4      28.0  338409.0           13.0           0.0           0.0
# ...     ...       ...            ...           ...           ...
# 26870  38.0  179488.0           12.0           0.0           0.0
# 26871  53.0   48343.0            9.0           0.0        1902.0
# 26872  28.0  100270.0           13.0           0.0           0.0
# 26873  42.0  227065.0           10.0       15024.0           0.0
# 26874  40.0      12.0           10.0           0.0           0.0
#
#        hours_per_week  income  workclass_ Federal-gov  workclass_ Local-gov  \
# 0                40.0   <=50K                   False                 False
# 1                13.0   <=50K                   False                 False
# 2                40.0   <=50K                   False                 False
# 3                40.0   <=50K                   False                 False
# 4                40.0   <=50K                   False                 False
# ...               ...     ...                     ...                   ...
# 26870            40.0   <=50K                   False                 False
# 26871            40.0    >50K                   False                 False
# 26872            40.0   <=50K                   False                  True
# 26873            32.0    >50K                   False                 False
# 26874            40.0   <=50K                   False                 False
#
#        workclass_ Never-worked  ...  native_country_ Portugal  \
# 0                        False  ...                     False
# 1                        False  ...                     False
# 2                        False  ...                     False
# 3                        False  ...                     False
# 4                        False  ...                     False
# ...                        ...  ...                       ...
# 26870                    False  ...                     False
# 26871                    False  ...                     False
# 26872                    False  ...                     False
# 26873                    False  ...                     False
# 26874                    False  ...                     False
#
#        native_country_ Puerto-Rico  native_country_ Scotland  \
# 0                            False                     False
# 1                            False                     False
# 2                            False                     False
# 3                            False                     False
# 4                            False                     False
# ...                            ...                       ...
# 26870                        False                     False
# 26871                        False                     False
# 26872                        False                     False
# 26873                        False                     False
# 26874                        False                     False
#
#        native_country_ South  native_country_ Taiwan  \
# 0                      False                   False
# 1                      False                   False
# 2                      False                   False
# 3                      False                   False
# 4                      False                   False
# ...                      ...                     ...
# 26870                  False                   False
# 26871                  False                   False
# 26872                  False                   False
# 26873                  False                   False
# 26874                  False                   False
#
#        native_country_ Thailand  native_country_ Trinadad&Tobago  \
# 0                         False                            False
# 1                         False                            False
# 2                         False                            False
# 3                         False                            False
# 4                         False                            False
# ...                         ...                              ...
# 26870                     False                            False
# 26871                     False                            False
# 26872                     False                            False
# 26873                     False                            False
# 26874                     False                            False
#
#        native_country_ United-States  native_country_ Vietnam  \
# 0                               True                    False
# 1                               True                    False
# 2                               True                    False
# 3                               True                    False
# 4                              False                    False
# ...                              ...                      ...
# 26870                           True                    False
# 26871                           True                    False
# 26872                           True                    False
# 26873                           True                    False
# 26874                           True                    False
#
#        native_country_ Yugoslavia
# 0                           False
# 1                           False
# 2                           False
# 3                           False
# 4                           False
# ...                           ...
# 26870                       False
# 26871                       False
# 26872                       False
# 26873                       False
# 26874                       False
#
# [26875 rows x 101 columns]

# %% [markdown]
# Label Encoding :

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
adult["education_encoded"] = le.fit_transform(adult["education"])
adult[["education", "education_encoded"]].head()
# Out:
#     education  education_encoded
# 0   Bachelors                  9
# 1   Bachelors                  9
# 2     HS-grad                 11
# 3        11th                  1
# 4   Bachelors                  9

# %%
cat_cols
# Out:
# Index(['workclass', 'education', 'marital_status', 'occupation',
#        'relationship', 'race', 'sex', 'native_country', 'income'],
#       dtype='object')

# %%
#Pros & Cons of Encoding Techniques

#One-Hot Encoding :

#Pros :

#No ordinal relationship assumed
#Works well for nominal data

#Cons :

#Increases dimensionality
#Not scalable for high-cardinality features

#Label Encoding :

#Pros :

#Memory efficient
#Fast and simple

#Cons :

#Introduces false ordinal relationship
#Can mislead distance-based models

# %% [markdown]
# Feature Engineering :
#
# Feature 1: Capital Gain Indicator :

# %%
adult["has_capital_gain"] = (adult["capital_gain"] > 0).astype(int)

# %%
#1 : individual has a capital gain
#0 : no capital gain
#Capital gains are strongly associated with higher income levels.

# %% [markdown]
# Rationale :

# %%
#Capital gains are strongly associated with higher income levels. Creating a binary indicator helps the model:
#Capture the presence or absence of capital gains
#Reduce sensitivity to extreme capital gain values
#Improve interpretability and predictive power

# %% [markdown]
# Feature 2: Work Intensity :

# %%
adult["work_intensity"] = adult["hours_per_week"] * adult["education_num"]

# %%
#hours-per-week : working effort
#education-num : education level
#Income is influenced not just by working hours or education individually, but by their combined effect.

# %% [markdown]
# Rationale :

# %%
#Income is influenced not just by working hours or education individually, but by their combined effect.
#The work_intensity feature represents how education and work commitment together impact earning potential.

# %% [markdown]
# Transformation of Skewed Features :

# %%
adult["capital_gain"].skew()       # check skew
#The capital-gain feature is highly right-skewed, meaning most values are small while a few extremely large values dominate the distribution
# Out:
# np.float64(11.810860624748464)

# %% [markdown]
# Log Transformation :

# %%
adult["capital_gain_log"] = np.log1p(adult["capital_gain"])

# %%
#Observation:

#The capital-gain feature is highly right-skewed, meaning most values are small while a few extremely large values dominate the distribution.

# %% [markdown]
# Justification :

# %%
#Log transformation is applied to handle skewness effectively

#Reduces the impact of extreme outliers

#Makes the distribution more symmetric

#Improves performance of linear and distance-based models

#log1p() is used to safely handle zero values
